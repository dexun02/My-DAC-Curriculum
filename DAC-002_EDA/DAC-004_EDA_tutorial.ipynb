# %% [markdown]
# 1. Read csv

# %%
import pandas as pd         
import numpy as np        
import matplotlib.pyplot as plt      
import seaborn as  sns

# %%
df = pd.read_csv(r"C:\Users\thund\Downloads\Netflix_Userbase.csv")
df.head()
df.dtypes
# Out:
# User ID               int64
# Subscription Type    object
# Monthly Revenue       int64
# Join Date            object
# Last Payment Date    object
# Country              object
# Age                   int64
# Gender               object
# Device               object
# Plan Duration        object
# dtype: object

# %% [markdown]
# 2. Clean Data

# %%
df.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
duplicated_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicated_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 10)

# %%
df.tail()
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#             Country  Age  Gender    Device Plan Duration
# 2495          Spain   28  Female  Smart TV       1 Month
# 2496          Spain   33  Female  Smart TV       1 Month
# 2497  United States   38    Male    Laptop       1 Month
# 2498         Canada   48  Female    Tablet       1 Month
# 2499  United States   35  Female  Smart TV       1 Month

# %% [markdown]
# 3. Read Data
#
#     a. subscription types

# %%
df['Subscription Type'].value_counts().plot(kind = 'bar', title = 'Type of subsciptions')
plt.rcParams['figure.figsize'] = (14,6)
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# Types of subscription types = Basic, Standard and Premium.

# %% [markdown]
#     b. Is it a monthly or yearly subscription?

# %%
type_of_sub = df['Plan Duration']
print(type_of_sub)
# Out:
# 0       1 Month
# 1       1 Month
# 2       1 Month
# 3       1 Month
# 4       1 Month
#          ...
# 2495    1 Month
# 2496    1 Month
# 2497    1 Month
# 2498    1 Month
# 2499    1 Month
# Name: Plan Duration, Length: 2500, dtype: object

# %% [markdown]
# monthly subscription

# %% [markdown]
# c. What are the different prices of the subscriptions?
# Basic = $10
# Standard = 12
# Premium = harh

# %% [markdown]
# 4. Visualise Data
#
#     a. Sales per Month

# %%
df["Join Date"].value_counts().sort_index().plot(kind = 'line' , title = 'Sales per month')
plt.rcParams['figure.figsize'] = (14,6)
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
#     b. Most Popular Subscription Type

# %%
df['Subscription Type'].value_counts().plot(kind = 'bar', title = 'Type of subsciptions')
plt.rcParams['figure.figsize'] = (14,6)
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# Basic is the most common, followed by standard and premium

# %% [markdown]
#     c. Gender VS Subscription Type

# %%
df['Gender'].value_counts().plot(kind = 'bar', title = 'Gender vs subscription type')
plt.()
